# %%
import pandas as pd

resume_df = pd.read_csv("../data/resume/final_merged_dataset2.csv")
##tell the number of rows and columns
##tuple containig rows and columns
print("Shape:")
print(resume_df.shape)

##it lists all the all the names of your columns in data frame 
##A list-like object containing the header names of your dataset
print("\nColumns:")
print(resume_df.columns)

##Sneak Peek (overview)
##it displays the first 5 rows of your data in a clean table
print("\nFirst 5 rows:")
print(resume_df.head())
# Out:
# Shape:
# (8234, 2)
#
# Columns:
# Index(['Resume', 'Category'], dtype='object')
#
# First 5 rows:
#                                               Resume          Category
# 0  Python Developer Python Developer Philadelphia...  Python_Developer
# 1  Python Developer Python Developer Python Devel...  Python_Developer
# 2  R&D Engineer R&D Engineer R&D Engineer - Nokia...  Python_Developer
# 3  Sr. Full Stack Developer Sr. Full Stack Develo...  Python_Developer
# 4  Sr. Full Stack Python Developer Sr. Full Stack...  Python_Developer

# %%
jd_df = pd.read_csv("../data/job_descriptions/job_title_des.csv")

print("Shape:")
print(jd_df.shape)

print("\nColumns:")
print(jd_df.columns)

print("\nFirst 5 rows:")
print(jd_df.head())
# Out:
# Shape:
# (2277, 3)
#
# Columns:
# Index(['Unnamed: 0', 'Job Title', 'Job Description'], dtype='object')
#
# First 5 rows:
#    Unnamed: 0             Job Title  \
# 0           0     Flutter Developer
# 1           1      Django Developer
# 2           2      Machine Learning
# 3           3         iOS Developer
# 4           4  Full Stack Developer
#
#                                      Job Description
# 0  We are looking for hire experts flutter develo...
# 1  PYTHON/DJANGO (Developer/Lead) - Job Code(PDJ ...
# 2  Data Scientist (Contractor)\n\nBangalore, IN\n...
# 3  JOB DESCRIPTION:\n\nStrong framework outside o...
# 4  job responsibility full stack engineer – react...

# %%
##os is imported 
## it is used for seeing in which folder your code is currently running in
##Create, delete, or rename folders on your desktop

import os

print(os.getcwd())

## get cwd stands for get current working directory
# Out:
# C:\Users\Akshit vashist\OneDrive\Desktop\intern ml\Interview-Question-Generator-Skill-Assessor\notebooks

# %%
##When your IT Skills dataset threw an error, you ran this block of code to see what was happening inside the file:import pandas as pd

file_path = "../data/skills/IT_Job_Roles_Skills.csv"
##rb is for read binary
with open(file_path, "rb") as f:
    print(f.read(100))
# Out:
# b'Job Title,Job Description,Skills,Certifications\r\nAdmin Big Data,"Responsible for managing and overse'

# %%
skills_df = pd.read_csv(
    "../data/skills/IT_Job_Roles_Skills.csv",
    encoding="latin1"
)

print(skills_df.head())
print(skills_df.columns)
print(skills_df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 skills_df = pd.read_csv(
#       2     "../data/skills/IT_Job_Roles_Skills.csv",
#       3     encoding="latin1"
#       4 )
#       6 print(skills_df.head())
#       7 print(skills_df.columns)
#
# NameError: name 'pd' is not defined
